# %% [markdown]
# # Importing Modules and Libraries

# %% [markdown]
# We use `requests` and `BeautifulSoup` for web scraping
#
# We use `hazm` for Persian text Processing.

# %%
import requests
from bs4 import BeautifulSoup

from hazm import *
from hazm.embedding import SentEmbedding
from sklearn.metrics.pairwise import cosine_similarity
import nltk
import numpy as np
import re

# %% [markdown]
# # Web Scraping

# %% [markdown]
# news1: sports - football
#
# news2: astronomy
#
# news3: sports - football

# %% [markdown]
# ## Getting data from URL

# %%
# NEWS URLs
NEWS1_url:str = r'https://www.tasnimnews.com/fa/news/1403/07/18/3174479/%D8%A2%D8%B2%D9%85%D9%88%D9%86-%D9%85%DB%8C-%D8%AF%D8%A7%D9%86%DB%8C%D9%85-%DA%86%D8%B7%D9%88%D8%B1-%D9%85%D9%82%D8%A7%D8%A8%D9%84-%D8%A7%D8%B2%D8%A8%DA%A9%D8%B3%D8%AA%D8%A7%D9%86-%D8%A8%D8%A7%D8%B2%DB%8C-%DA%A9%D9%86%DB%8C%D9%85'
NEWS2_url:str = r'https://www.tasnimnews.com/fa/news/1403/07/14/3172106/%D8%AC%D9%85%D8%B9-%D8%A2%D9%88%D8%B1%DB%8C-3-%D9%BE%D8%AA%D8%A7%D8%A8%D8%A7%DB%8C%D8%AA-%D8%AF%D8%A7%D8%AF%D9%87-%D9%87%D8%A7%DB%8C-%D9%85%D8%A7%D9%87%D9%88%D8%A7%D8%B1%D9%87-%D8%A7%DB%8C-%D8%AA%D9%88%D8%B3%D8%B7-%D8%B3%D8%A7%DB%8C%D8%AA-%D9%88%D8%B1%D8%A7%D9%85%DB%8C%D9%86'
NEWS3_url:str = r'https://www.tasnimnews.com/fa/news/1403/07/18/3174432/%D8%A8%DA%AF%DB%8C%D8%B1%DB%8C%D8%B3%D8%AA%D8%A7%DB%8C%D9%86-%D8%AF%D8%B1-%D9%BE%D8%A7%DB%8C%D8%A7%D9%86-%D9%81%D8%B5%D9%84-%D9%85%D9%86%DA%86%D8%B3%D8%AA%D8%B1%D8%B3%DB%8C%D8%AA%DB%8C-%D8%B1%D8%A7-%D8%AA%D8%B1%DA%A9-%D9%85%DB%8C-%DA%A9%D9%86%D8%AF'

# Requests to the server
news1_response = requests.get(NEWS1_url)
news2_response = requests.get(NEWS2_url)
news3_response = requests.get(NEWS3_url)


# Basically handling error
if news1_response.status_code != 200:
    raise Exception(f'The First NEWS Was not fetch with code: {news1_response.status_code}')

if news2_response.status_code != 200:
    raise Exception(f'The Second NEWS Was not fetch with code: {news2_response.status_code}')

if news3_response.status_code != 200:
    raise Exception(f'The Third NEWS Was not fetch with code: {news3_response.status_code}')

# Saving html contents in a dictionary
html_contents = {'n1': news1_response.text, 'n2': news2_response.text, 'n3':news3_response.text}

# %% [markdown]
# ## Parsing HTML contents with soup
# The text of each article is in a `div` with the `story` class.

# %%
extracted_texts = dict()

for idx, html_content in html_contents.items():
    soup = BeautifulSoup(html_content, 'html.parser')
    article = soup.find('div', class_='story').getText()
    article = article.replace('\u200c', ' ')
    article = article.replace('انتهای پیام/', '')
    extracted_texts[idx] = article

# %%
extracted_texts
# Out:
# {'n1': ' - اخبار ورزشی - به گزارش خبرنگار اعزامی خبرگزاری تسنیم از ازبکستان، سردار آزمون مهاجم تیم ملی فوتبال ایران در نشست خبری پیش از دیدار مقابل ازبکستان در مرحله سوم انتخابی جام جهانی 2026 در قاره آسیا، اظهار داشت: بازی سختی است، همیشه جلوی ازبکستان بازی سختی داشتیم، ولی ما به عنوان بازیکن می دانیم که چطور مقابل این تیم بازی کنیم. سه امتیاز این بازی برای ما اهمیت زیادی دارد و امیدواریم بتوانیم این سه امتیاز را به دست بیاوریم و راه مان را همین طور ادامه دهیم.قلعه نویی:از هر نظر آماده بازی با ازبکستانیم/کشور ما امن است\xa0در ادامه نشست خبری یک خبرنگار ازبکستانی از امیر قلعه نویی سؤالی درباره ضعف خط دفاعی تیم ملی ایران پرسید و گفت با این ضعف چه راهکاری برای مقابله با خط حمله ازبکستان اندیشیده اند که این سؤال با واکنش سردار آزمون مواجه شد و مهاجم تیم ملی کشورمان گفت: ببخشید اما با وجود اینکه شما این ضعف را می گویید، اما آخرین باری که ما را بردید کی بوده است؟!مهاجم تیم ملی فوتبال کشورمان در واکنش به کری خوانی یک بازیکن ازبکستان گفت: به عنوان بازیکن کری خوانی را دوست دارم، اما اگر منطقی باشد. ما می دانیم جلوی ازبکستان چطور بازی کنیم، اما به همه تیم ها احترام می گذاریم و این هم به فرهنگ ما ایرانی ها برمی گردد،\xa0 ولی آخرین بازی که ازبکستان ما را به چالش کشانده 12 سال پیش بوده و بعد از آن بردی مقابل ما نداشته است. این نشان می دهد ما می دانیم چطور مقابل این تیم بازی کنیم. فردا قطعاً با تمام قوا به زمین می آییم و هیچ استرسی نداریم و بازی خودمان را انجام می دهیم.',
#  'n2': ' - اخبار ویژه نامه ها - به گزارش خبرنگار فضا و نجوم خبرگزاری تسنیم، امیر مجید فخری؛ رئیس سازمان جغرافیایی نیروهای مسلح امروز در مراسم افتتاحیه هفته جهانی فضا که با حضور ستار هاشمی، وزیر ارتباطات، در پژوهشگاه فضایی ایران برگزار شد، با اشاره به نقش وزارت دفاع در توسعه صنعت فضایی در سه حوزه اصلی پرتاب، ساخت ماهواره ها و بهره برداری از داده های فضایی گفت: در موضوع تغییرات اقلیمی که محور این همایش است، سه عنصر اساسی برای پایش دقیق تغییرات اقلیمی لازم است. نخستین عنصر، ابزارهای پایش است که ماهواره ها مهم ترین آنها محسوب می شوند.رئیس سازمان جغرافیایی نیروهای مسلح با تاکید بر نیاز به بررسی های طولانی مدت در حوزه اقلیم و ضرورت ارائه آمار و تحلیل های مبتنی بر مدل ها و الگوریتم های تحقیقی مناسب افزود: ذخیره سازی داده ها و داشتن داده های بلندمدت از عناصر کلیدی است و دانش پردازش این داده ها به ما کمک می کند تا به نتایج بهتری دست یابیم.وی همچنین تاکید کرد: باید همگام با سایر دستگاه ها، به ویژه سازمان هواشناسی، پایگاه های داده اقلیمی بلندمدت در کشور ایجاد کنیم.برافراشتن پرچم ایران در مدار ژئو با ماهواره پژوهش3وی به نگرانی نیروهای مسلح از پدیده «دستکاری اقلیم» در سطح جهانی اشاره و تصریح کرد: فناوری هایی که در دنیا مطرح هستند، امکان دستکاری اقلیم در برخی مناطق را فراهم می کنند.فخری با اشاره به 103 سال سابقه سازمان جغرافیایی نیروهای مسلح در علوم نقشه برداری تاکید کرد: این سازمان به عنوان رکن اصلی تامین اطلاعات جغرافیایی در غرب آسیا برای نیروهای مسلح، با تجهیز به سامانه های نوین و دانش لازم، خدمات موثر هم در بخش کشوری و هم در بخش نظامی ارائه می دهد.وی در ادامه از دریافت داده های ماهواره ای از سال 1381 در سایت سپهر ورامین خبر داد و گفت: این سایت تاکنون حدود 3 پتابایت داده های تصویری ماهواره ای جمع آوری کرده است و اکنون به تجهیزات جدیدی مجهز شده است.رئیس سازمان جغرافیایی نیروهای مسلح با اشاره به توانایی رصدخانه ژئوفیزیک این سازمان برای رصد اعماق فضا از طریق چندین سنجنده اعلام کرد: برنامه ریزی برای ایجاد این رصدخانه در 7 نقطه کشور برای جمع آوری داده های لایه های بالای جو انجام شده است و این داده ها در اختیار دستگاه های بهره بردار قرار خواهد گرفت.وی همچنین به نصب و راه اندازی 154 ایستگاه GMSS در سراسر کشور اشاره و خاطرنشان کرد: این ایستگاه ها علاوه بر ارائه داده های موقعیتی و ناوبری دریایی به نیروهای مسلح و دستگاه های دولتی، قابلیت دریافت و پردازش داده های جوی را نیز دارند.فخری از راه اندازی رصدخانه جغرافیایی کشور به عنوان ایده ای که از 5 تا 6 سال پیش در سازمان مطرح شده، خبر داد و گفت: این رصدخانه مسئولیت جمع آوری داده های داخل و خارج کشور را برعهده دارد. این داده ها شامل عکس های هوایی و نقشه های پوششی از غرب آسیا و نقشه های با مقیاس کوچک تر هستند که طی 103 سال در سازمان جغرافیایی ذخیره شده اند و در یک پایگاه داده موجود هستند. این داده ها برای ناوبری شناورهای نیروی دریایی و هرمتحرکی که بر روی زمین فعالیت می کند، استفاده می شود.وی همچنین تاکید کرد: نیروهای مسلح به عنوان نخستین سازمان های حاضر در مواقع بحران، باید به آخرین اطلاعات دسترسی داشته باشند. سامانه ای با عنوان «اطلس مخاطرات طبیعی» در حال تکمیل است که شامل اطلاعات مربوط به زلزله، سیل، فرونشست، خشکسالی، زمین لرزه، موج گرما، سرما، یخبندان و گردوغبار است و این اطلاعات به مدیریت بحران ارائه می شود.رئیس سازمان جغرافیایی نیروهای مسلح در پایان به چالش های تغییرات اقلیمی در حوزه هایی مانند امنیت غذایی، مهاجرت و امنیت اجتماعی اشاره کرد و گفت: حساسیت نیروهای مسلح به این مسائل ایجاب می کند که این سازمان تحلیل های دقیق و پیش بینی های بلندمدتی برای منطقه ارائه کند.وی تأکید کرد: رخدادهایی مانند باران های سیل آسا و تغییرات ناگهانی دما نیازمند رصد دقیق و ارائه تحلیل های به روز است تا تصمیم گیری های صحیح و کارآمد در سطوح مختلف مدیریتی صورت گیرد.',
#  'n3': ' - اخبار ورزشی - به گزارش خبرگزاری تسنیم، چیکی بگیریستاین، مدیر ورزشی اسپانیایی باشگاه منچسترسیتی و یکی از عوامل اصلی موفقیت های این تیم در سال های اخیر، ورزشگاه اتحاد را ترک خواهد کرد.طبق اعلام نشریه اتلتیک انگلیس؛ مدیرورزشی پیشین بارسلونا که موفق ترین مدیر ورزشی در تاریخ باشگاه منچسترسیتی است، تصمیم گرفته که در پایان فصل به کار خود در نیمه آبی شهر منچستر پایان دهد.انتشار این خبر در شرایطی است که درباره آینده دیگر عامل اصلی موفقیت های اخیر سیتی، یعنی پپ گواردیولا هم ابهام هایی وجود دارد. گواردیولا نیز مانند بگیریستاین تا ماه ژوئن سال 2025 قرارداد دارد و زمزمه هایی مبنی بر جدایی او نیز شنیده می شود و گمانه زنی هایی درباره احتمال مجازات سنگین باشگاه منچسترسیتی به دلیل نقض قوانین بازی جوانمردانه مالی شنیده می شود.گواردیولا: یکی، دو کار دیگر برای تکمیل کار هجومی  کم داریمبگیریستاین 13 سال پیش کار خود را در منچسترسیتی آغاز کرد و در دوره کاری او به عنوان مدیر ورزشی، تیم آبی شهر منچستر موفق به کسب 21 جام شد.در همین حال فابریتزیو رومانو، خبرنگار سرشناس نقل و انتقالات فوتبال اروپا، مدعی شده است که باشگاه منچسترسیتی جانشین بگیریستاین را شناسایی و جای او را با هوگو ویانا، مدیرورزشی پرتغالی باشگاه اسپورتینگ لیسبون پر خواهد کرد. بگیریستاین که پپ گواردیولا از او به عنوان خاص ترین فرد زندگی  حرفه ای اش و یکی از باهوش ترین افراد دنیای فوتبال یاد کرد، سال 2012 به استخدام منچسترسیتی درآمد و از آن زمان تا کنون بازیکنانی مانند فرناندینیو، آلوارو نگردو، خسوس ناواس، کوین دی بروینه، رحیم استرلینگ، ایلکای گوندوگان، آیمریک لاپورت، برناردو سیلوا، ادرسون، رودری، جک گریلیش، خولیان آلوارس، ارلینگ هالند و ... را برای این باشگاه جذب کرد.'}

# %% [markdown]
# # Processing Articles' Text

# %% [markdown]
# ## Keyword Extraction

# %%
grammers = [
"""
NP:
        {<NOUN,EZ>?<NOUN.*>}    # Noun(s) + Noun(optional)

""",

"""
NP:
        {<NOUN.*><ADJ.*>?}    # Noun(s) + Adjective(optional)

"""
]
## you can also add your own grammer to be extracted from the text...

# %%
def extract_candidates(tagged, grammer):
    keyphrase_candidate = set()
    np_parser = nltk.RegexpParser(grammer)
    trees = np_parser.parse_sents(tagged)
    for tree in trees:
        for subtree in tree.subtrees(filter=lambda t: t.label() == 'NP'):  # For each nounphrase
            # Concatenate the token with a space
            keyphrase_candidate.add(' '.join(word for word, tag in subtree.leaves()))
    keyphrase_candidate = {kp for kp in keyphrase_candidate if len(kp.split()) <= 5}
    keyphrase_candidate = list(keyphrase_candidate)
    return keyphrase_candidate

# %%
pos_model_path = 'models/pos_tagger.model'
tagger = POSTagger(model = pos_model_path)

# %%
sent2vec_model_path = 'models/sent2vec/sent2vec-naab.model'
sent2vec_model = SentEmbedding(sent2vec_model_path)

# %%
# The dictionary
text_vectors = dict()

# %%
normalizer = Normalizer()
stop_words = stopwords_list()

for idx, text in extracted_texts.items():
    print(f'_______________ Processing NEWS {idx[1]} _______________')
    
    print('------Normalizing\n')
    # Normalizer    
    normalize_text = normalizer.normalize(text)
    
    print('------Tokenizing\n')
    # Tokenized
    tokenize_text = [word_tokenize(sent) for sent in sent_tokenize(normalize_text)]
    
    print('------Stop Word Removal\n')
    # Stop Word Removal    
    tokenized_text = []
    for sent in tokenize_text:
        sentence = []
        for word in sent:
            if word not in stop_words:
                sentence.append(word)
        tokenized_text.append(sentence)
    tokenize_text = tokenized_text
    
    print('------Extracting keyword candidates\n')
    token_tag_list = tagger.tag_sents(tokenize_text)
    
    print('------Extracting keyword candidates\n')
    # Extracting keyword candidates
    all_candidates = set()
    for grammer in grammers:
        all_candidates.update(extract_candidates(token_tag_list, grammer))



    print(f'------keywords for NEWS {idx[1]}\n')
    all_candidates = np.array(list(all_candidates))
    print('------------------------------')
    print(np.array(list(all_candidates)))
    print(f'Num candidates {len(list(all_candidates))}')
    print('------------------------------')
    
    print('------Embedding the text\n')
    # Embedding the keywords using sent2vec model
    candidates_concatinate = ' '.join(all_candidates)
    text_vector = sent2vec_model[candidates_concatinate]
    text_vectors[idx] = text_vector
    
    print(f'NEWS {idx[1]} vector: {text_vector.shape}')
# Out:
# _______________ Processing NEWS 1 _______________
# ------Normalizing
#
# ------Tokenizing
#
# ------Stop Word Removal
#
# ------Extracting keyword candidates
#
# ------Extracting keyword candidates
#
# ------keywords for NEWS 1
#
# ------------------------------
# ['نویی' 'ادامه خبری' 'فوتبال کشورمان' 'مقابله' 'گزارش خبرنگار' 'بازی'
#  'فوتبال' 'بازیکن' 'قلعه' 'مقابله خط' 'امتیاز' 'فوتبال ایران'
#  'بازیکن ازبکستان' 'تسنیم' 'دست' 'گزارش' 'مرحله' 'تیم ملی' 'اهمیت'
#  'بازی سختی' 'خوانی' 'ایرانی\u200cها' 'کشورمان' 'سؤالی' 'ازبکستان' 'خبری'
#  'عنوان' 'مرحله انتخابی' 'ایران' 'آزمون' 'حمله' 'واکنش' 'کشور امن' 'ادامه'
#  'سال' 'سؤال واکنش' 'بازی ازبکستانیم' 'مهاجم تیم' 'امیر' 'نشان'
#  'عنوان بازیکن' 'جام' 'زمین' 'آزمون مهاجم' 'امتیاز بازی' 'قلعه نویی' 'قوا'
#  'احترام' 'تیم بازی' 'کشور' 'بازی ازبکستان' 'استرسی' 'خبرنگار ازبکستانی'
#  'کری' 'خبرنگار اعزامی' 'جام جهانی' 'سردار' 'ضعف' 'چالش' 'خط دفاعی' 'تیم'
#  'تیم\u200cها' 'قاره' 'کری خوانی' 'خط' 'ازبکستانیم' 'ضعف راهکاری' 'آسیا'
#  '؟!' 'دوست' 'مان' 'اظهار' 'واکنش کری' 'خبرنگار' 'حمله ازبکستان' 'دیدار'
#  'امیر قلعه' 'خبرگزاری' 'مهاجم' 'فرهنگ' 'اخبار ورزشی' 'راهکاری' 'سؤال'
#  'خبرگزاری تسنیم' 'ضعف خط' 'انجام' 'قاره آسیا' 'اخبار']
# Num candidates 88
# ------------------------------
# ------Embedding the text
#
# NEWS 1 vector: (300,)
# _______________ Processing NEWS 2 _______________
# ------Normalizing
#
# ------Tokenizing
#
# ------Stop Word Removal
#
# ------Extracting keyword candidates
#
# ------Extracting keyword candidates
#
# ------keywords for NEWS 2
#
# ------------------------------
# ['عنصر اساسی' 'پایش' 'اعلام' 'ایستگاه' 'اختیار' 'نیروی دریایی'
#  'پژوهشگاه فضایی' 'سازمان رصد' 'نجوم' 'مدار ژئو' 'زلزله' 'ضرورت ارائه'
#  'ارائه داده\u200cهای' 'پایگاه\u200cهای' 'راه\u200cاندازی' 'مخاطرات طبیعی'
#  'رخدادهایی' 'مراسم' 'علوم نقشه\u200cبرداری' 'دانش' 'بحران' 'منطقه'
#  'گزارش خبرنگار' 'جمع\u200cآوری داده\u200cهای' 'منطقه ارائه'
#  'امنیت اجتماعی' 'اطلاعات' 'عکس\u200cهای' 'سال سازمان' 'قابلیت'
#  'نقش وزارت' 'ماهواره\u200cها' 'باران\u200cهای' 'آمار' 'نگرانی نیروهای'
#  'اعماق فضا' 'تسنیم' 'اشاره توانایی' 'هفته' 'الگوریتم\u200cهای' 'طریق'
#  'دستکاری' 'رکن' 'دست' 'عناصر' 'ناوبری' 'نقش' 'محور'
#  'فناوری\u200cهایی دنیا' 'تصمیم\u200cگیری\u200cهای صحیح' 'اشاره' 'توانایی'
#  'گزارش' 'حوزه\u200cهایی' 'دریافت' 'دستکاری اقلیم' 'عنوان ایده\u200cای'
#  'رصدخانه جغرافیایی' 'ارائه تحلیل\u200cهای' 'شناورهای نیروی'
#  'پایان چالش\u200cهای' 'تغییرات اقلیمی' 'ارائه' 'نقشه\u200cهای مقیاس'
#  'ژئوفیزیک' 'هواشناسی' 'سامانه\u200cای' 'افتتاحیه' 'ساخت' 'اطلس'
#  'رصدخانه مسئولیت' 'عنوان سازمان\u200cهای' 'داده\u200cهای تصویری' 'پایگاه'
#  'خارج کشور' 'سازمان عنوان' 'ذخیره\u200cسازی' 'تغییرات ناگهانی' 'سیل'
#  'دستگاه\u200cها' 'ایجاد' 'عنوان' 'دنیا مطرح' 'مهاجرت' 'مسائل' 'ایران'
#  'خدمات' 'فعالیت' 'اعماق' 'عنصر' 'رصد دقیق' 'حوزه'
#  'دستگاه\u200cهای بهره\u200cبردار' 'تامین اطلاعات' 'رصدخانه'
#  'راه\u200cاندازی رصدخانه' 'ارتباطات' 'نصب' 'ایستگاه GMSS' 'موج گرما'
#  'نقشه\u200cهای پوششی' 'اختیار دستگاه\u200cهای' 'محور همایش' 'دسترسی'
#  'پایان' 'اطلاعات دسترسی' 'هفته جهانی' 'تجهیزات جدیدی'
#  'تحلیل\u200cهای مبتنی' 'زمین\u200cلرزه' 'تأکید' 'تکمیل اطلاعات'
#  'حضور ستار' 'ادامه' 'سال' 'کشور ایجاد' 'مدیریت' 'سازمان هواشناسی'
#  'برنامه\u200cریزی' 'بهره\u200cبرداری' 'امنیت' 'علوم'
#  'آمار تحلیل\u200cهای' 'مهاجرت امنیت' 'مسئولیت' 'امیر مجید'
#  'همگام دستگاه\u200cها' 'سایت سپهر' 'مجید' 'پیش\u200cبینی\u200cهای'
#  'داده\u200cهای فضایی' 'تحلیل\u200cهای دقیق' 'خبر' 'غرب' 'امیر'
#  'ایران برگزار' 'رکن اصلی' 'داده\u200cهای جوی' 'پدیده' 'زمین'
#  'داده\u200cهای ماهواره\u200cای' 'سامانه\u200cهای نوین' 'همگام'
#  'تحلیل\u200cهای به\u200cروز' 'داده\u200cها' 'سرما' 'سطوح' 'سپهر' 'پرچم'
#  'صنعت فضایی' 'حوزه اقلیم' 'سازمان تحلیل\u200cهای' 'ماهواره' 'برافراشتن'
#  'فناوری\u200cهایی' 'عکس\u200cهای هوایی' 'دما نیازمند' 'اطلاعات مدیریت'
#  'سابقه سازمان' 'سازمان' 'کشور' 'ژئو' 'خارج' 'ابزارهای' 'تکمیل'
#  'وزیر ارتباطات' 'مقیاس کوچک\u200cتر' 'مناطق فراهم' 'موضوع تغییرات' 'مدار'
#  'پرتاب' 'تاکید بررسی\u200cهای' 'دستگاه\u200cهای دولتی' 'ستار' 'دفاع'
#  'همایش' 'اقلیم' 'لایه\u200cهای' 'تامین' 'وزیر' 'برنامه\u200cریزی ایجاد'
#  'ایده\u200cای' 'داده\u200cهای' 'هرمتحرکی' 'سازمان مطرح\u200cشده'
#  'ماهواره پژوهش' 'فضا' 'حضور' 'شناورهای' 'گرما' 'حساسیت نیروهای'
#  'دفاع توسعه' 'مسائل ایجاب' 'ماهواره\u200cها مهم\u200cترین' 'ایجاب'
#  'سابقه' 'قرار' 'کمک' 'تاکید' 'ایستگاه\u200cها' 'سطح جهانی'
#  'نقشه\u200cبرداری' 'سطوح مختلف' 'عناصر کلیدی' 'بررسی\u200cهای طولانی'
#  'جو' 'مدل\u200cها' 'دما' 'نقطه' 'نیروهای' 'مواقع بحران' 'گردوغبار'
#  'نیروهای مسلح' 'پژوهش' 'پایگاه موجود' 'مراسم افتتاحیه' 'پایش دقیق'
#  'پتابایت' 'تجهیز سامانه\u200cهای' 'آسیا' 'سازمان\u200cهای حاضر' 'تجهیز'
#  'سازمان جغرافیایی' 'یخبندان' 'سایت' 'استفاده' 'نقشه\u200cهای' 'پردازش'
#  'ویژه\u200cنامه\u200cها' 'سطح' 'رصد' 'اطلس مخاطرات'
#  'تصمیم\u200cگیری\u200cهای' 'خبرنگار' 'ساخت ماهواره\u200cها'
#  'پیش\u200cبینی\u200cهای بلندمدتی' 'نصب راه\u200cاندازی' 'نگرانی'
#  'ناوبری دریایی' 'صنعت' 'امنیت غذایی' 'موج' 'چالش\u200cهای'
#  'برافراشتن پرچم' 'نتایج' 'ورامین' 'خبرگزاری' 'قابلیت دریافت' 'خدمات موثر'
#  'الگوریتم\u200cهای تحقیقی' 'حوزه اصلی' 'وزارت'
#  'بهره\u200cبرداری داده\u200cهای' 'نتایج بهتری' 'پایگاه\u200cهای اقلیمی'
#  'مواقع' 'دستگاه\u200cهای' 'هاشمی' 'رصدخانه ژئوفیزیک' 'ابزارهای پایش'
#  'غرب آسیا' 'تغییرات' 'اخبار ویژه\u200cنامه\u200cها'
#  'ذخیره\u200cسازی داده\u200cها' 'باران\u200cهای سیل\u200cآسا' 'مناطق'
#  'فراهم' 'اخبار' 'دانش پردازش' 'جو انجام\u200cشده' 'خبرگزاری تسنیم'
#  'جمع\u200cآوری تجهیزات' 'رئیس' 'موضوع' 'توسعه' 'داده\u200cهای بلندمدت'
#  'پردازش داده\u200cهای' 'جمع\u200cآوری' 'حساسیت' 'ضرورت'
#  'اطلاعات جغرافیایی' 'پژوهشگاه' 'سنجنده' 'فخری' 'خشکسالی' 'نقطه کشور'
#  'تصریح' 'موقعیتی' 'ادامه دریافت' 'یخبندان گردوغبار' 'رئیس سازمان' 'صورت']
# Num candidates 292
# ------------------------------
# ------Embedding the text
#
# NEWS 2 vector: (300,)
# _______________ Processing NEWS 3 _______________
# ------Normalizing
#
# ------Tokenizing
#
# ------Stop Word Removal
#
# ------Extracting keyword candidates
#
# ------Extracting keyword candidates
#
# ------keywords for NEWS 3
#
# ------------------------------
# ['شهر' 'اعلام' 'دنیای فوتبال' 'باشگاه جذب' 'ادرسون' 'سیلوا' 'کسب'
#  'مدعی باشگاه' 'گزارش خبرگزاری' 'جدایی' 'ترک' 'ایلکای گوندوگان' 'فوتبال'
#  'نقض' 'قوانین' 'بگیریستاین' 'تاریخ' 'برناردو' 'دنیای' 'ماه ژوئن' 'بروینه'
#  'تسنیم' 'گمانه\u200cزنی\u200cهایی' 'دلیل' 'بازی جوانمردانه'
#  'فوتبال اروپا' 'باشگاه منچسترسیتی' 'گزارش' 'باشگاه اسپورتینگ' 'آغاز دوره'
#  'عنوان خاص\u200cترین' 'قرارداد' 'پپ' 'انگلیس' 'لیسبون' 'گریلیش'
#  'بازیکنانی' 'رومانو' 'نقل انتقالات' 'احتمال مجازات' 'نگردو' 'عنوان'
#  'دوره' 'گوندوگان' 'رودری' 'عوامل اصلی' 'اروپا' 'پایان' 'تیم آبی'
#  'موفقیت\u200cهای' 'مدعی' 'مدیر' 'عوامل' 'زندگی' 'آلوارو' 'سال'
#  'قوانین بازی' 'منچستر موفق' 'ایلکای' 'گواردیولا' 'خبر' 'آیمریک'
#  'مدیرورزشی' 'تصمیم' 'منچستر' 'کار تکمیل' 'عنوان مدیر' 'جام' 'خولیان'
#  'منچسترسیتی' 'درآمد' 'عامل اصلی' 'شرایطی' 'رحیم استرلینگ' 'ماه'
#  'فابریتزیو' 'شناسایی' 'دلیل نقض' 'ناواس' 'بارسلونا موفق\u200cترین' 'نقل'
#  'مدیرورزشی پیشین' 'ویانا' 'تکمیل' 'عامل' 'زمزمه\u200cهایی مبنی' 'فصل کار'
#  'چیکی' 'استخدام' 'اتحاد' 'مجازات سنگین' 'کاری' 'موفقیت\u200cهای تیم'
#  'جذب' 'قرارداد زمزمه\u200cهایی' 'سال کار' 'آغاز' 'ابهام\u200cهایی' 'سیتی'
#  'انتقالات' 'جک' 'هوگو' 'کوین' 'جانشین' 'داریمبگیریستاین' 'زمان' 'تیم'
#  'جانشین بگیریستاین' 'شناسایی هوگو' 'آینده' 'آلوارس' 'کار' 'انتشار'
#  'کار هجومی' 'احتمال' 'خولیان آلوارس' 'خبرنگار' 'انتشار خبر'
#  'خبرنگار سرشناس' 'اعلام نشریه' 'دی' 'یاد' 'استرلینگ' 'تصمیم پایان'
#  'خبرگزاری' 'مدیر ورزشی' 'ورزشگاه' 'رحیم' 'ورزشگاه اتحاد' 'اتلتیک'
#  'فرناندینیو' 'درآمد زمان' 'اخبار ورزشی' 'اسپورتینگ' 'کار آبی'
#  'اتلتیک انگلیس' 'بارسلونا' 'فصل' 'لاپورت' 'زندگی حرفه\u200cای\u200cاش'
#  'خسوس' 'نشریه' 'موفقیت\u200cهای سیتی' 'شهر منچستر' 'ژوئن' 'تاریخ باشگاه'
#  'اخبار' 'ارلینگ' 'باشگاه' 'استخدام منچسترسیتی']
# Num candidates 150
# ------------------------------
# ------Embedding the text
#
# NEWS 3 vector: (300,)

# %% [markdown]
# ## Calculating Cosine Similarity

# %% [markdown]
# Football - Astronomy

# %%
text_vectors['n1'].dot(text_vectors['n2']) / (np.linalg.norm(text_vectors['n1'], ord=2) * np.linalg.norm(text_vectors['n2'], ord=2))
# Out:
# 0.3460327

# %% [markdown]
# Football - Football

# %%
text_vectors['n1'].dot(text_vectors['n3']) / (np.linalg.norm(text_vectors['n1'], ord=2) * np.linalg.norm(text_vectors['n3'], ord=2))
# Out:
# 0.36653438

# %% [markdown]
# Football - Astronomy

# %%
text_vectors['n2'].dot(text_vectors['n3']) / (np.linalg.norm(text_vectors['n2'], ord=2) * np.linalg.norm(text_vectors['n3'], ord=2))
# Out:
# 0.22850972

# %% [markdown]
# Football Football has the most cosine similarity, as we expected
